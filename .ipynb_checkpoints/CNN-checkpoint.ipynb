# %%
# Import libraries
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
data_dir = r"C:\Users\admin\Desktop\DL AAT\chest_xray"

# %%
def count_images(path):
    normal = len(os.listdir(os.path.join(path, 'NORMAL')))
    pneumonia = len(os.listdir(os.path.join(path, 'PNEUMONIA')))
    return normal, pneumonia

train_normal, train_pneu = count_images(os.path.join(data_dir, 'train'))
val_normal, val_pneu = count_images(os.path.join(data_dir, 'val'))
test_normal, test_pneu = count_images(os.path.join(data_dir, 'test'))

print("📊 Image Counts")
print(f"Train - NORMAL: {train_normal}, PNEUMONIA: {train_pneu}")
print(f"Validation - NORMAL: {val_normal}, PNEUMONIA: {val_pneu}")
print(f"Test - NORMAL: {test_normal}, PNEUMONIA: {test_pneu}")
# Out:
# 📊 Image Counts
# Train - NORMAL: 1342, PNEUMONIA: 3876
# Validation - NORMAL: 9, PNEUMONIA: 9
# Test - NORMAL: 234, PNEUMONIA: 390

# %%
import matplotlib.image as mpimg
import random

def show_sample_image(class_name):
    folder = os.path.join(data_dir, 'train', class_name)
    img_file = random.choice(os.listdir(folder))
    img_path = os.path.join(folder, img_file)
    img = mpimg.imread(img_path)
    plt.imshow(img, cmap='gray')
    plt.title(f"{class_name} Sample")
    plt.axis('off')
    plt.show()

# Show one NORMAL and one PNEUMONIA image
show_sample_image('NORMAL')
show_sample_image('PNEUMONIA')

# %%
Step 2

# %%
import os
print(os.listdir(r'C:\Users\admin\Desktop\DL AAT\chest_xray'))
data_dir = r"C:\Users\admin\Desktop\DL AAT\chest_xray"



train_dir = os.path.join(data_dir, 'train')
val_dir   = os.path.join(data_dir, 'val')
test_dir  = os.path.join(data_dir, 'test')




#2.2 Set Up ImageDataGenerators

# Set image size and batch size
from tensorflow.keras.preprocessing.image import ImageDataGenerator

IMG_SIZE = (150, 150)
BATCH_SIZE = 32

# For training: apply augmentation + rescale
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)

# For validation and test: only rescale
test_val_datagen = ImageDataGenerator(rescale=1./255)

# Load training images
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary'  # pneumonia vs normal → binary classification
)

# Load validation images
val_generator = test_val_datagen.flow_from_directory(
    val_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary'
)

# Load test images
test_generator = test_val_datagen.flow_from_directory(
    test_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary',
    shuffle=False  # Important for evaluation/prediction
)
# Out:
# ['.DS_Store', 'test', 'train', 'val']
# Found 5216 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
📊 2.3 Preview Augmented Images

# %%
# Display 5 sample augmented training images
sample_images, sample_labels = next(train_generator)

plt.figure(figsize=(10, 5))
for i in range(5):
    plt.subplot(1, 5, i + 1)
    plt.imshow(sample_images[i])
    plt.title("Pneumonia" if sample_labels[i] == 1 else "Normal")
    plt.axis('off')
plt.tight_layout()
plt.show()

# %%
✅ STEP 3: Building the CNN Model (Jupyter Notebook)

# %%
🛠️ 3.2 Build a Simple CNN with Keras

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout

from tensorflow.keras.layers import BatchNormalization

model = Sequential([
    Input(shape=(150, 150, 3)),

    Conv2D(32, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(64, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(128, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])






model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model_architecture.png', show_shapes=True, show_layer_names=True)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)                    │ (None, 148, 148, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 148, 148, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 74, 74, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 72, 72, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 72, 72, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 36, 36, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 34, 34, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 34, 34, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 17, 17, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 36992)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │       4,735,104 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,829,377 (18.42 MB)
#  Trainable params: 4,828,929 (18.42 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
✅ STEP 4: Train the CNN Model (Jupyter Notebook)

# %%
🔁 4.1 Start Model Training

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

callbacks = [
    EarlyStopping(monitor='val_loss', patience=4, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, verbose=1)
]

history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=20,
    validation_data=val_generator,
    validation_steps=val_generator.samples // val_generator.batch_size,
    callbacks=callbacks
)
# Out:
# Epoch 1/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 151s 927ms/step - accuracy: 0.8936 - loss: 0.2565 - val_accuracy: 0.5000 - val_loss: 9.2738 - learning_rate: 0.0010
# Epoch 2/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 182s 1s/step - accuracy: 0.9039 - loss: 0.2193 - val_accuracy: 0.5000 - val_loss: 4.1476 - learning_rate: 0.0010
# Epoch 3/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 163s 997ms/step - accuracy: 0.9044 - loss: 0.2219 - val_accuracy: 0.5000 - val_loss: 9.7919 - learning_rate: 0.0010
# Epoch 4/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 955ms/step - accuracy: 0.9098 - loss: 0.2124
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 156s 957ms/step - accuracy: 0.9098 - loss: 0.2125 - val_accuracy: 0.5000 - val_loss: 4.7693 - learning_rate: 0.0010
# Epoch 5/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 166s 1s/step - accuracy: 0.9171 - loss: 0.1676 - val_accuracy: 0.6875 - val_loss: 0.8306 - learning_rate: 2.0000e-04
# Epoch 6/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 156s 955ms/step - accuracy: 0.9258 - loss: 0.1652 - val_accuracy: 0.5000 - val_loss: 2.2032 - learning_rate: 2.0000e-04
# Epoch 7/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 936ms/step - accuracy: 0.9283 - loss: 0.1493
# Epoch 7: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 153s 937ms/step - accuracy: 0.9283 - loss: 0.1493 - val_accuracy: 0.5625 - val_loss: 1.0872 - learning_rate: 2.0000e-04
# Epoch 8/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 150s 920ms/step - accuracy: 0.9305 - loss: 0.1454 - val_accuracy: 0.8125 - val_loss: 0.5045 - learning_rate: 4.0000e-05
# Epoch 9/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 370s 2s/step - accuracy: 0.9322 - loss: 0.1523 - val_accuracy: 0.5625 - val_loss: 0.9806 - learning_rate: 4.0000e-05
# Epoch 10/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9214 - loss: 0.1428
# Epoch 10: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 254s 2s/step - accuracy: 0.9215 - loss: 0.1428 - val_accuracy: 0.6250 - val_loss: 0.9329 - learning_rate: 4.0000e-05
# Epoch 11/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 274s 2s/step - accuracy: 0.9361 - loss: 0.1549 - val_accuracy: 0.8125 - val_loss: 0.5083 - learning_rate: 8.0000e-06
# Epoch 12/20
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9298 - loss: 0.1583
# Epoch 12: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 271s 2s/step - accuracy: 0.9298 - loss: 0.1582 - val_accuracy: 0.6875 - val_loss: 0.5878 - learning_rate: 8.0000e-06

# %%
📈 4.2 Plot Training vs Validation Accuracy/Loss

# %%
import matplotlib.pyplot as plt

# Accuracy
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# Loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
✅ STEP 5: Evaluate the Model on the Test Set (Jupyter Notebook)

# %%
📉 5.1 Evaluate Accuracy on Test Data

# %%
test_loss, test_accuracy = model.evaluate(test_generator)
print(f"✅ Test Accuracy: {test_accuracy:.4f}")
print(f"❌ Test Loss: {test_loss:.4f}")
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 866ms/step - accuracy: 0.8548 - loss: 0.3805
# ✅ Test Accuracy: 0.8846
# ❌ Test Loss: 0.2903

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report, accuracy_score
import matplotlib.pyplot as plt


pred_probs = model.predict(test_generator, verbose=1)

# ✅ Step 2: Convert probabilities to binary predictions (0 = Normal, 1 = Pneumonia)
pred_labels = (pred_probs > 0.5).astype(int).flatten()

# ✅ Step 3: Get actual labels from test generator
true_labels = test_generator.classes

# ✅ Step 4: Confusion Matrix
cm = confusion_matrix(true_labels, pred_labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Normal', 'Pneumonia'])
disp.plot(cmap='Blues')
plt.title("Confusion Matrix")
plt.show()

# ✅ Step 5: Classification Report
print("🔍 Classification Report:")
print(classification_report(true_labels, pred_labels, target_names=['Normal', 'Pneumonia']))

# ✅ Step 6: Accuracy Score
acc = accuracy_score(true_labels, pred_labels)
print(f"✅ Final Accuracy: {acc:.4f}")
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 22s 996ms/step
# 🔍 Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       0.88      0.80      0.84       234
#    Pneumonia       0.89      0.94      0.91       390
#
#     accuracy                           0.88       624
#    macro avg       0.88      0.87      0.87       624
# weighted avg       0.88      0.88      0.88       624
#
# ✅ Final Accuracy: 0.8846

# %%
import matplotlib.pyplot as plt
import numpy as np

# Class names from the generator
class_names = list(test_generator.class_indices.keys())  # e.g., ['NORMAL', 'PNEUMONIA']

# Number of images to display
n = 20

# Load a batch of images
images = []
for i in range(n):
    img = test_generator[i][0][0]  # Get image
    images.append(img)

# Plot predictions vs actual
plt.figure(figsize=(14, 8))

for i in range(n):
    plt.subplot(4, 6, i + 1)

    img = images[i]
    pred = pred_labels[i]
    true = true_labels[i]

    label_pred = class_names[pred]
    label_true = class_names[true]
    color = 'green' if pred == true else 'red'

    plt.imshow(img)
    plt.title(f"P: {label_pred}\nA: {label_true}", color=color, fontsize=9)
    plt.axis('off')

plt.tight_layout()
plt.show()
